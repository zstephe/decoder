# %%
import enchant
broker = enchant.Broker()
broker.describe()
broker.list_languages()
# Out:
# ['sk_SK',
#  'mk',
#  'nds',
#  'tk',
#  'be',
#  'zu',
#  'ny',
#  'ml',
#  'lv',
#  'sv',
#  'cs',
#  'de_DE',
#  'fa',
#  'pt_BR',
#  'nn',
#  'ku',
#  'fr_CH',
#  'br',
#  'sk',
#  'ru',
#  'he',
#  'sw',
#  'fy',
#  'bg',
#  'el',
#  'sl',
#  'be_SU',
#  'gd',
#  'mn',
#  'af',
#  'la',
#  'uz',
#  'tn',
#  'qu',
#  'ar',
#  'hr',
#  'or',
#  'pt_PT',
#  'fo',
#  'it',
#  'rw',
#  'en_CA',
#  'en_US',
#  'en_AU',
#  'grc',
#  'en',
#  'da',
#  'ta',
#  'srd',
#  'tl',
#  'gr',
#  'sc',
#  'eo',
#  'hsb',
#  'ky',
#  'te',
#  'de_CH',
#  'hi',
#  'kn',
#  'ca',
#  'vi',
#  'it_IT',
#  'hu',
#  'fr_FR',
#  'fr',
#  'mr',
#  'tr',
#  'cy',
#  'ro',
#  'yi',
#  'mg',
#  'pl',
#  'nl_NL',
#  'hus',
#  'sv_SE',
#  'ms',
#  'ia',
#  'pa',
#  'gu',
#  'wa',
#  'de',
#  'sr',
#  'hil',
#  'mt',
#  'ast',
#  'gv',
#  'fi',
#  'es',
#  'mi',
#  'de_AT',
#  'bn',
#  'csb',
#  'en_GB',
#  'uk',
#  'am',
#  'tet',
#  'et',
#  'lt',
#  'hy',
#  'gl',
#  'nl',
#  'es_ES',
#  'id',
#  'ga',
# ...

# %%
enchant.list_languages()
# Out:
# ['sk_SK',
#  'mk',
#  'nds',
#  'tk',
#  'be',
#  'zu',
#  'ny',
#  'ml',
#  'lv',
#  'sv',
#  'cs',
#  'de_DE',
#  'fa',
#  'pt_BR',
#  'nn',
#  'ku',
#  'fr_CH',
#  'br',
#  'sk',
#  'ru',
#  'he',
#  'sw',
#  'fy',
#  'bg',
#  'el',
#  'sl',
#  'be_SU',
#  'gd',
#  'mn',
#  'af',
#  'la',
#  'uz',
#  'tn',
#  'qu',
#  'ar',
#  'hr',
#  'or',
#  'pt_PT',
#  'fo',
#  'it',
#  'rw',
#  'en_CA',
#  'en_US',
#  'en_AU',
#  'grc',
#  'en',
#  'da',
#  'ta',
#  'srd',
#  'tl',
#  'gr',
#  'sc',
#  'eo',
#  'hsb',
#  'ky',
#  'te',
#  'de_CH',
#  'hi',
#  'kn',
#  'ca',
#  'vi',
#  'it_IT',
#  'hu',
#  'fr_FR',
#  'fr',
#  'mr',
#  'tr',
#  'cy',
#  'ro',
#  'yi',
#  'mg',
#  'pl',
#  'nl_NL',
#  'hus',
#  'sv_SE',
#  'ms',
#  'ia',
#  'pa',
#  'gu',
#  'wa',
#  'de',
#  'sr',
#  'hil',
#  'mt',
#  'ast',
#  'gv',
#  'fi',
#  'es',
#  'mi',
#  'de_AT',
#  'bn',
#  'csb',
#  'en_GB',
#  'uk',
#  'am',
#  'tet',
#  'et',
#  'lt',
#  'hy',
#  'gl',
#  'nl',
#  'es_ES',
#  'id',
#  'ga',
# ...
